# %% [markdown]
# <a href="https://colab.research.google.com/github/Deependrashukla/Machine-Learning/blob/main/Linear_Regression_Using_Coordinate_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Mean squared error from residual
def mse_from_e(residual):
    return ((residual**2).sum())/len(residual)

# Mean Squared Error of X.w - y
def mean_squared_error(X, y, w):
    return mse_from_e(np.dot(X,w) - y)

# %%
# Generate a sawtooth weight vector
def genu(d, m):
    u = np.arange(d) * (2 * (np.arange(d) % 2) - 1)
    u = m * u / np.sqrt(np.dot(u, u))
    return u

# Generate random data
def genx(n, d):
    X = np.random.randint(0, 2, (n, d))
    X[:,int(d/2)] = 1
    return X

# Generate targets and add noise
def gent(X, u, noise):
    n = X.shape[0]
    y = np.dot(X, u).reshape(n, 1)
    y += noise * np.var(y) * np.random.randn(n, 1)
    return y

# Generate data, weights, and targets
def gimme_data_regres(n, d, noise=0.1):
    u = genu(d, 1.0)
    X = genx(n, d)
    y = gent(X, u, noise)
    mse_gen = mean_squared_error(X, y, u)
    print('Generator Loss={0:8.5f}\n'.format(mse_gen))
    return X, u, y

# %%
# Plot loss as a function of epoch
def loss_plotter(vlist, fname):
    vr = vlist[0]
    vn = vlist[1]
    if not use_notebook:
        plt.figure(fname)
        plt.plot(range(1, 1+len(vr)), vr,
            range(1, 1+len(vn)), vn,
            linewidth=2, linestyle='-', marker='o')
        plt.legend(('rep', 'nor'))
        plt.grid()
        xt = np.arange(1, 1 + max(len(vr), len(vn)))
        _ = plt.xticks(xt)
        _ = plt.xlabel('Epoch', fontsize=14)
        _ = plt.ylabel(fname, fontsize=14)
    if not use_notebook:
        plt.show(block=False)
    return

# Scatter plot of predicted vs. observed targets
def loss_scatter(X, y, w, fname):
    if not use_notebook:
        plt.figure(fname)
    plt.scatter(y, X.dot(w), edgecolors=(0,0,0))
    plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
    plt.grid()
    plt.xlabel('$y$', fontsize=14)
    plt.ylabel('$\hat{y}$', fontsize=14)
    if not use_notebook:
        plt.show(block=False)

# %%
# sample new index (w/ or w/o replacement)
def sample_new_index(d, replace=1):
    if replace:
        ind = np.random.randint(d)
    else:
        if 'prm' not in sample_new_index.__dict__:
            sample_new_index.prm = np.random.permutation(d)
            sample_new_index.head = 0

        ind=sample_new_index.prm[sample_new_index.head]
        sample_new_index.head+=1

        if sample_new_index.head == d:
            sample_new_index.head = 0
            del sample_new_index.prm
    return ind

# %%
# calculate the change to w[j] wrt current margins z
# xjs is the squared norm of the jth column of X, a.k.a. ||xj||^2
def delta_wj(e, xj, xjs):

    a = -(np.dot(e.T,xj)/xjs)
    return a

# Return new values for w[j] and residual
def update(wj, e, xj, xjs):

    a = delta_wj(e,xj,xjs)
    e = e + a*xj
    wj = wj + a
    return wj,e

# %%
# Initialize all variables using the zero vector for w
# (Initialize w as the zero vector)
# You should return w, xjs, residual
def initialize(X, y):

    w = np.zeros((d,1))
    residual = -y
    xjs = np.sum(X**2,axis=0)
    return w, xjs, residual

# %%
# Check whether termination condition is met
def mse_check(mse_p, mse_c, eps):

    (mse_p - mse_c)/mse_c <= eps

# %%
# Linear regression using coordinate decent
def linear_regression_cd(X, y, epochs=100, eps=0.001, replace=1):
    w, xjs, residual = initialize(X, y)
    mse_cd = [mse_from_e(residual)]
    n, d = X.shape
    for e in range(d * epochs):
        j = sample_new_index(d, replace)
        xj = X[:,j].reshape(n, 1)
        w[j], residual = update(w[j], residual, xj, xjs[j])
        if (e + 1) % d == 0:
            mse_cd.append(mse_from_e(residual))
            print('Epoch: {0:2d}  MSE: {1:5.3f}'.format(int((e+1)/d), mse_cd[-1]))
            if mse_check(mse_cd[-2], mse_cd[-1], eps): break
    return w, mse_cd

# %%
# ---------------- Main for linear regression using Coordinate Descent --------------

np.random.seed(17)
n, d, noise = 1000, 20, 1.0
myeps = 1e-4

[X, u, y] = gimme_data_regres(n, d, noise)

mse_list = []
[wr, mse_r] = linear_regression_cd(X, y, eps=myeps)
mse_list.append(mse_r)
[wn, mse_n] = linear_regression_cd(X, y, eps=myeps, replace=0)
mse_list.append(mse_n)
use_notebook=False
if not use_notebook:
    plt.close('all')
loss_plotter(mse_list, 'MSE')
loss_scatter(X, y, wn, 'True vs. Predicted Outcome')
# Out:
# Generator Loss=559.01124
#
# Epoch:  1  MSE: 0.194
# Epoch:  2  MSE: 0.130
# Epoch:  3  MSE: 0.084
# Epoch:  4  MSE: 0.078
# Epoch:  5  MSE: 0.074
# Epoch:  6  MSE: 0.063
# Epoch:  7  MSE: 0.059
# Epoch:  8  MSE: 0.058
# Epoch:  9  MSE: 0.058
# Epoch: 10  MSE: 0.057
# Epoch: 11  MSE: 0.057
# Epoch: 12  MSE: 0.057
# Epoch: 13  MSE: 0.057
# Epoch: 14  MSE: 0.057
# Epoch: 15  MSE: 0.057
# Epoch: 16  MSE: 0.057
# Epoch: 17  MSE: 0.057
# Epoch: 18  MSE: 0.057
# Epoch: 19  MSE: 0.056
# Epoch: 20  MSE: 0.056
# Epoch: 21  MSE: 0.056
# Epoch: 22  MSE: 0.056
# Epoch: 23  MSE: 0.056
# Epoch: 24  MSE: 0.056
# Epoch: 25  MSE: 0.056
# Epoch: 26  MSE: 0.056
# Epoch: 27  MSE: 0.056
# Epoch: 28  MSE: 0.056
# Epoch: 29  MSE: 0.056
# Epoch: 30  MSE: 0.056
# Epoch: 31  MSE: 0.056
# Epoch: 32  MSE: 0.056
# Epoch: 33  MSE: 0.056
# Epoch: 34  MSE: 0.056
# Epoch: 35  MSE: 0.056
# Epoch: 36  MSE: 0.056
# Epoch: 37  MSE: 0.056
# Epoch: 38  MSE: 0.056
# Epoch: 39  MSE: 0.056
# Epoch: 40  MSE: 0.056
# Epoch: 41  MSE: 0.056
# Epoch: 42  MSE: 0.056
# Epoch: 43  MSE: 0.056
# Epoch: 44  MSE: 0.056
# Epoch: 45  MSE: 0.056
# Epoch: 46  MSE: 0.056
# Epoch: 47  MSE: 0.056
# Epoch: 48  MSE: 0.056
# Epoch: 49  MSE: 0.056
# Epoch: 50  MSE: 0.056
# Epoch: 51  MSE: 0.056
# Epoch: 52  MSE: 0.056
# Epoch: 53  MSE: 0.056
# Epoch: 54  MSE: 0.056
# Epoch: 55  MSE: 0.056
# Epoch: 56  MSE: 0.056
# Epoch: 57  MSE: 0.056
# Epoch: 58  MSE: 0.056
# Epoch: 59  MSE: 0.056
# Epoch: 60  MSE: 0.056
# Epoch: 61  MSE: 0.056
# Epoch: 62  MSE: 0.056
# Epoch: 63  MSE: 0.056
# Epoch: 64  MSE: 0.056
# Epoch: 65  MSE: 0.056
# Epoch: 66  MSE: 0.056
# Epoch: 67  MSE: 0.056
# Epoch: 68  MSE: 0.056
# Epoch: 69  MSE: 0.056
# Epoch: 70  MSE: 0.056
# Epoch: 71  MSE: 0.056
# Epoch: 72  MSE: 0.056
# Epoch: 73  MSE: 0.056
# Epoch: 74  MSE: 0.056
# Epoch: 75  MSE: 0.056
# Epoch: 76  MSE: 0.056
# Epoch: 77  MSE: 0.056
# Epoch: 78  MSE: 0.056
# Epoch: 79  MSE: 0.056
# Epoch: 80  MSE: 0.056
# Epoch: 81  MSE: 0.056
# Epoch: 82  MSE: 0.056
# Epoch: 83  MSE: 0.056
# Epoch: 84  MSE: 0.056
# Epoch: 85  MSE: 0.056
# Epoch: 86  MSE: 0.056
# Epoch: 87  MSE: 0.056
# Epoch: 88  MSE: 0.056
# Epoch: 89  MSE: 0.056
# Epoch: 90  MSE: 0.056
# Epoch: 91  MSE: 0.056
# Epoch: 92  MSE: 0.056
# Epoch: 93  MSE: 0.056
# Epoch: 94  MSE: 0.056
# Epoch: 95  MSE: 0.056
# Epoch: 96  MSE: 0.056
# Epoch: 97  MSE: 0.056
# Epoch: 98  MSE: 0.056
# Epoch: 99  MSE: 0.056
# Epoch: 100  MSE: 0.056
# Epoch:  1  MSE: 0.117
# Epoch:  2  MSE: 0.072
# Epoch:  3  MSE: 0.061
# Epoch:  4  MSE: 0.059
# Epoch:  5  MSE: 0.058
# Epoch:  6  MSE: 0.058
# Epoch:  7  MSE: 0.057
# Epoch:  8  MSE: 0.057
# Epoch:  9  MSE: 0.057
# Epoch: 10  MSE: 0.057
# Epoch: 11  MSE: 0.057
# Epoch: 12  MSE: 0.057
# Epoch: 13  MSE: 0.057
# Epoch: 14  MSE: 0.057
# Epoch: 15  MSE: 0.057
# Epoch: 16  MSE: 0.057
# Epoch: 17  MSE: 0.057
# Epoch: 18  MSE: 0.056
# Epoch: 19  MSE: 0.056
# Epoch: 20  MSE: 0.056
# Epoch: 21  MSE: 0.056
# Epoch: 22  MSE: 0.056
# Epoch: 23  MSE: 0.056
# Epoch: 24  MSE: 0.056
# Epoch: 25  MSE: 0.056
# Epoch: 26  MSE: 0.056
# Epoch: 27  MSE: 0.056
# Epoch: 28  MSE: 0.056
# Epoch: 29  MSE: 0.056
# Epoch: 30  MSE: 0.056
# Epoch: 31  MSE: 0.056
# Epoch: 32  MSE: 0.056
# Epoch: 33  MSE: 0.056
# Epoch: 34  MSE: 0.056
# Epoch: 35  MSE: 0.056
# Epoch: 36  MSE: 0.056
# Epoch: 37  MSE: 0.056
# Epoch: 38  MSE: 0.056
# Epoch: 39  MSE: 0.056
# Epoch: 40  MSE: 0.056
# Epoch: 41  MSE: 0.056
# Epoch: 42  MSE: 0.056
# Epoch: 43  MSE: 0.056
# Epoch: 44  MSE: 0.056
# Epoch: 45  MSE: 0.056
# Epoch: 46  MSE: 0.056
# Epoch: 47  MSE: 0.056
# Epoch: 48  MSE: 0.056
# Epoch: 49  MSE: 0.056
# Epoch: 50  MSE: 0.056
# Epoch: 51  MSE: 0.056
# Epoch: 52  MSE: 0.056
# Epoch: 53  MSE: 0.056
# Epoch: 54  MSE: 0.056
# Epoch: 55  MSE: 0.056
# Epoch: 56  MSE: 0.056
# Epoch: 57  MSE: 0.056
# Epoch: 58  MSE: 0.056
# Epoch: 59  MSE: 0.056
# Epoch: 60  MSE: 0.056
# Epoch: 61  MSE: 0.056
# Epoch: 62  MSE: 0.056
# Epoch: 63  MSE: 0.056
# Epoch: 64  MSE: 0.056
# Epoch: 65  MSE: 0.056
# Epoch: 66  MSE: 0.056
# Epoch: 67  MSE: 0.056
# Epoch: 68  MSE: 0.056
# Epoch: 69  MSE: 0.056
# Epoch: 70  MSE: 0.056
# Epoch: 71  MSE: 0.056
# Epoch: 72  MSE: 0.056
# Epoch: 73  MSE: 0.056
# Epoch: 74  MSE: 0.056
# Epoch: 75  MSE: 0.056
# Epoch: 76  MSE: 0.056
# Epoch: 77  MSE: 0.056
# Epoch: 78  MSE: 0.056
# Epoch: 79  MSE: 0.056
# Epoch: 80  MSE: 0.056
# Epoch: 81  MSE: 0.056
# Epoch: 82  MSE: 0.056
# Epoch: 83  MSE: 0.056
# Epoch: 84  MSE: 0.056
# Epoch: 85  MSE: 0.056
# Epoch: 86  MSE: 0.056
# Epoch: 87  MSE: 0.056
# Epoch: 88  MSE: 0.056
# Epoch: 89  MSE: 0.056
# Epoch: 90  MSE: 0.056
# Epoch: 91  MSE: 0.056
# Epoch: 92  MSE: 0.056
# Epoch: 93  MSE: 0.056
# Epoch: 94  MSE: 0.056
# Epoch: 95  MSE: 0.056
# Epoch: 96  MSE: 0.056
# Epoch: 97  MSE: 0.056
# Epoch: 98  MSE: 0.056
# Epoch: 99  MSE: 0.056
# Epoch: 100  MSE: 0.056
